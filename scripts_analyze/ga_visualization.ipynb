# %%
import selfies as sf
import random
from janus.crossover import get_joint_sim, crossover_smiles
from janus.mutate import mutate_smiles

alphabet=sf.get_semantic_robust_alphabet() # Gets the alphabet of robust symbols
smiles_1 = "O=C(Oc1ccc[nH]1)c1nccs1"
sf_1 = sf.encoder(smiles_1)
smiles_1_output = sf.decoder(sf_1)
print(sf_1)
print(smiles_1_output)
print(sf.decoder("[O][=C][Branch1_1][Branch2_1][O][C][=C][C][=C][NHexpl][Ring1][Branch1_1][C][=N][C][=C][S][Ring1][Branch1_1]"))
# Out:
# [O][=C][Branch1_1][Branch2_2][O][C][=C][C][=C][NHexpl][Ring1][Branch1_1][C][=N][C][=C][S][Ring1][Branch1_1]
# O=C(OC1=CC=C[NH]1)C2=NC=CS2
# O=C(OC=CC=C=[NH])C1=NC=CS1
# ['C=CC(=O)COc1ccc[nH]1', 'O=C(OC1=CCC1)c1ncc[nH]1', 'C=CC=CC(=O)Oc1ccc[nH]1', 'C=CN=CC(=O)Oc1ccc[nH]1', 'O=C(OC1=CCCN1)c1ncc[nH]1', 'C=CC(=O)OC(=CNc1nccs1)N=C', 'CC=COC(=O)c1ncc[nH]1', 'N=CNC(=O)Oc1[nH]ccc1O', 'C=CC=C(N)OC(=O)c1ncc[nH]1', 'O=C(C=CS)c1ncc[nH]1', 'NC=CC(=O)c1ncc[nH]1', 'CSC(=N)C(=O)Oc1ncc[nH]1', 'O=CC(=O)OC1=c2[nH]ccc2=C=N1', 'O=CC(=O)Oc1c[nH]cc[nH]cn1', 'O=CC(=O)Oc1[nH]cc2cc[nH]c12', 'CC(=C=O)Oc1ncc[nH]1', 'CC(=O)Oc1ccn2nc[nH]c12', 'CC(=O)Oc1c[nH]cc[nH]cn1', 'CC(=O)Oc1cocc[nH]cn1', 'CC=COOC(=O)c1ncc[nH]1', 'C#CSCC(=O)Oc1ncc[nH]1', 'C=CN(C)C(=O)Oc1ccc[nH]1', 'CC(=O)Oc1nc[nH]c1C', 'N=CC(=O)Oc1[nH]ccc1ON', 'C=CSC=CC=CC(=O)Oc1ccc[nH]1', 'C=CSNC(=O)Oc1ccc[nH]1', 'C=NN=CC(=O)Oc1ccc[nH]1', 'C=CSCC(=O)Oc1ccc[nH]1', 'C=CC(=O)C=C1N=Cc2ccsc21', 'C=CC(=O)OC1N=Cc2ccsc21', 'O=Cc1ncc[nH]1', 'O=C(OC1=CN1)C1=NC=CC1', 'CN=CC(=O)Oc1ccn[nH]1', 'O=CCNCOC(=O)c1ncc[nH]1', 'O=C(CO)Oc1[nH]cc2cc[nH]c12', 'CCC(=O)Oc1[nH]cc2cc[nH]c12', 'N=C=CC=COC(=O)c1ncc[nH]1', 'C=CSC(=O)C(=O)Oc1ccc[nH]1', 'C=CSC(=N)C(=O)Oc1ccc[nH]1', 'C=CN=C(S)C(=O)Oc1ccc[nH]1', 'CCC(=O)Oc1ncn2ccsc12', 'C=CSC(=NN)C(=O)Oc1ccn[nH]1', 'NCC(=O)Oc1nc[nH]c1N', 'C=[SH]CN=CC(=O)Oc1ccc[nH]1', 'C=CN=C(SC)C(=O)Cc1ccc[nH]1', 'CC=CC=C(N)OC(=O)c1ncc[nH]1', 'CC(=O)OC1=C2NC=C[SH]2C=N1', 'NC(=O)OC1=
oc1ccc[nH]1', 'Cc1[nH]cc[nH]ccc1OC=O', 'CNCCC(=O)Oc1cnc[nH]1', 'CC(=O)ONC=Cc1ccc[nH]1', 'C=CC(=C)OCc1nccs1', 'O=CNC(=O)Oc1ccn[nH]1', 'C=CN=C1C(Oc2ccc[nH]2)S1=O', 'O=C(OC1=CC=CC1)C1=NCNS1', 'O=C(CS)Oc1ncco1', 'C=CC(C)Cc1ccc[nH]1', 'CC=CNc1[nH]cnc1OC(C)=O', 'C=CC(=O)Oc1c[nH]ccnn[nH]1', 'C=CC(=O)OC1N=Cc2cc[nH]c21', 'NC(=O)COc1ccn2cc[nH]c12', 'O=COn1ccc2nc[nH]c21', 'O=c1[nH]ccn2cnc(c2)o1', 'O=COc1cnc[nH]1', 'CSC=CN=CC(=O)Oc1cnc[nH]1', 'O=CC(=O)Nc1ccc[nH]1', 'O=NC=CC(CS)Oc1ncc[nH]1', 'CC(C=O)OC1=c2[nH]ccc2=C=N1', 'CC(C=O)Oc1[nH]cc2cc[nH]c12', 'NCC(=O)OC1=C=NC=CNC=N1', 'NC=COC(=O)c1ccc[nH]1', 'O=C1C=COC1c1ncc[nH]1', 'C=C(SC=CO)C(=O)Cc1ccc[nH]1', 'C=CCCC(=N)Oc1ccc[nH]1', 'C=CSCCC(=O)Oc1cnc[nH]1', 'O=C(NC=CS)Oc1c[nH]cn1', 'C=CC(=O)OOc1ncc[nH]1', 'CC=CN=CC(=O)Oc1ccc[nH]1', 'O=C(C=NC=CS)Oc1ccc[nH]1', 'O=CON=CC(=O)Oc1ccc[nH]1', 'O=C(C=NC=C=S)Oc1ccc[nH]1', 'O=C(C=NCOS)Oc1ccc[nH]1', 'O=C(C=NOC=S)Oc1ccc[nH]1', 'O=C=CN=CC(=O)Oc1ccc[nH]1', 'C=C=CSCC(=O)Oc1ccc[nH]1', 'C=C=CC=NC(=O)Oc1ccc[nH]1', 'O=CCN=CC(=O)Oc1ccc[nH]1', 'CSCN=CC(=O)Oc1ccc[nH]1', 'O=C(ON1CC=CN1)C1=CN1', 'N=C(OC=CN)C(=O)c1ccc[nH]1', 'O=CCCOc1c[nH]cc[nH]cn1', 'O=CC=CN=C1N=Cc2cc[nH]c21', 'N ...
# [ 0.3465953   0.34559919  0.34171009 ... -0.07966349 -0.21028646
#  -0.21028646]

# %%
mutate_smiles(smiles_1, alphabet=["[C]"] * 500, num_random_samples=10, num_mutations=3, num_sample_frags=3)
# Out:
# ['C#CSCC(=O)Oc1ccc[nH]1',
#  'CC=CNCOC#[PH](=O)C=NC=C=S',
#  'CC=CN[S-](#CCl)OC(=O)c1nccs1',
#  'C#CSC[C+]C(=O)OC1C=CN1',
#  'O=CC1C=CS1',
#  'O=C(c1ccc[nH]1)c1nccs1',
#  'C=CN=CC(=O)OC1=CC=CC1',
#  'O=C(C=S)Oc1ccc[nH]1',
#  'O=C(OC1=CC=CC1)c1nccs1',
#  'C=NC(=O)Oc1ccc[nH]1',
#  'O=[PH](#COc1ccc[nH]1)C=NC=C=S',
#  'N=C(Oc1ccc[nH]1)c1nccs1',
#  'CN=C1Sc2c1c2=O',
#  'CC=CC=C(O)c1nccs1',
#  'CC1=CSC(=O)CO1',
#  'CC=CN[S-](#CCl)OC(N)OC=NC=C=S',
#  'O=C(Oc1ccc[nH]1)C1=CS1',
#  'C1=C[O+]C(OCc2nccs2)N1',
#  'O=C(Oc1ccc[nH]1)c1nccs1',
#  'C=CN=COC(=[S+])OC1=CC=CC1',
#  'C1=CNC(c2nccs2)C=C1',
#  'CC1=CSC1=O',
#  'O=C(OC1(Cl)CC=CN1)c1nccs1',
#  'O=C(C=NC=CNS)Oc1ccc[nH]1',
#  'C=C=[N-]',
#  'CC1=CC=C1CSC=C=O',
#  'N=C(c1ccc[nH]1)c1nccs1',
#  'CC=CCNCOC#[PH](=O)C=NC=C=S']

# %%
smiles_1 = "O=C(Oc1ccc[nH]1)c1nccs1"
sf_1 = sf.encoder(smiles_1)
print(sf_1)
mutated_smiles_1 = "O=C(c1ccc[nH]1)c1nccs1"
mutated_sf_1 = sf.encoder(mutated_smiles_1)
print(mutated_sf_1)
smiles_2 = "C=CC(=O)Oc1ncn2cc[nH]c12"
sf_2 = sf.encoder(smiles_2)
print(sf_2)
crossover_smiles_12 = "C(=Cc1ncn2cc[nH]c12)c1nccs1"
crossover_sf_12 = sf.encoder(crossover_smiles_12)
print(crossover_sf_12)

all_crossover_smiles = crossover_smiles(mutated_smiles_1 + "xxx" + smiles_2, 30)
all_joint_similarity = get_joint_sim(all_crossover_smiles, mutated_smiles_1, smiles_2)
print(all_crossover_smiles[:10])
print(all_joint_similarity[:10])
# Out:
# [O][=C][Branch1_1][Branch2_2][O][C][=C][C][=C][NHexpl][Ring1][Branch1_1][C][=N][C][=C][S][Ring1][Branch1_1]
# [O][=C][Branch1_1][Branch2_1][C][=C][C][=C][NHexpl][Ring1][Branch1_1][C][=N][C][=C][S][Ring1][Branch1_1]
# [C][=C][C][Branch1_2][C][=O][O][C][N][=C][N][C][=C][NHexpl][C][Expl=Ring1][Branch2_1][Ring1][Branch1_1]
# [C][Branch1_2][=C][=C][C][N][=C][N][C][=C][NHexpl][C][Expl=Ring1][Branch2_1][Ring1][Branch1_1][C][=N][C][=C][S][Ring1][Branch1_1]
# ['C=CC(=O)Cc1ccc[nH]1', 'O=C(C=CC1=CN1)c1ncc[nH]1', 'O=C(C=S)c1ncc[nH]1', 'C=CC(=C=O)Sc1ccc[nH]1', 'NC=CC(=O)Oc1c[nH]ccscn1', 'C=CC(=O)Oc1ccc[nH]1', 'N=CC(=O)Cc1ncc[nH]1', 'CN=CC(=O)c1ncc[nH]1', 'O=c1ccncn2cc[nH]c2co1', 'C=C(OC)C(=O)c1ncc[nH]1']
# [0.37168876 0.3381466  0.33057254 0.32673853 0.31600642 0.314446
#  0.31435304 0.31435304 0.3122981  0.31093153]

# %%
smiles_1 = "O=C(Oc1ccc[nH]1)c1nccs1"
sf_1 = sf.encoder(smiles_1)
print(sf_1)
mutated_smiles_1 = "O=C(c1ccc[nH]1)c1nccs1"
mutated_sf_1 = sf.encoder(mutated_smiles_1)
print(mutated_sf_1)
# Out:
# [O][=C][Branch1_1][Branch2_2][O][C][=C][C][=C][NHexpl][Ring1][Branch1_1][C][=N][C][=C][S][Ring1][Branch1_1]
# [O][=C][Branch1_1][Branch2_1][C][=C][C][=C][NHexpl][Ring1][Branch1_1][C][=N][C][=C][S][Ring1][Branch1_1]
